# %%
# Jacob Macy
# Module_2_Lab
# This app requests the entry of a last name, first name, 
# and GPA to determine whether or not the student made the Dean's List or Honor Roll
while True:
    last_name = input('Enter last name:')
    if last_name == 'ZZZ':
        break
    first_name = input('Enter first name:')
    GPA = float(input('Enter GPA:'))
    if GPA >= 3.5:
        print("You made the Dean's List")
    elif GPA >= 3.25:
        print("You made the Honor Roll")
    else:
        print("You didn't make either :(")
# Out:
# Enter last name: ZZZ
